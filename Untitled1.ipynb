# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score

from scipy import signal
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
daily_cases = pd.read_csv('new_cases.csv')

# %%
daily_cases
# Out:
#            date  new_cases
# 0    2020-03-22    69662.0
# 1    2020-03-23    85702.0
# 2    2020-03-24    82320.0
# 3    2020-03-25   102036.0
# 4    2020-03-26   125660.0
# ..          ...        ...
# 249  2020-11-26  1165420.0
# 250  2020-11-27  1372580.0
# 251  2020-11-28  1172982.0
# 252  2020-11-29   976416.0
# 253  2020-11-30  1013410.0
#
# [254 rows x 2 columns]

# %%
X = daily_cases.date
# X = np.reshape(X, (len(X), 1))

y = daily_cases.new_cases

# %%
X
# Out:
# 0      2020-03-22
# 1      2020-03-23
# 2      2020-03-24
# 3      2020-03-25
# 4      2020-03-26
#           ...
# 249    2020-11-26
# 250    2020-11-27
# 251    2020-11-28
# 252    2020-11-29
# 253    2020-11-30
# Name: date, Length: 254, dtype: object

# %%
plt.figure(figsize=(16,6))
plt.xaxis.set_major_locator(ticker.MultipleLocator(10))
sns.lineplot(x = X, y = y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-bbd838b62996> in <module>
#       1 plt.figure(figsize=(16,6))
# ----> 2 plt.xaxis.set_major_locator(ticker.MultipleLocator(10))
#       3 sns.lineplot(x = X, y = y)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xaxis'

# %%
pf = PolynomialFeatures(degree=4)
Xp = pf.fit_transform(X)
Xp
# Out:
# array([[1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00],
#        [1.00000000e+00, 2.00000000e+00, 4.00000000e+00, 8.00000000e+00,
#         1.60000000e+01],
#        ...,
#        [1.00000000e+00, 2.51000000e+02, 6.30010000e+04, 1.58132510e+07,
#         3.96912600e+09],
#        [1.00000000e+00, 2.52000000e+02, 6.35040000e+04, 1.60030080e+07,
#         4.03275802e+09],
#        [1.00000000e+00, 2.53000000e+02, 6.40090000e+04, 1.61942770e+07,
#         4.09715208e+09]])

# %%
md2 = LinearRegression()
md2.fit(Xp, y)
trendp = md2.predict(Xp)

# %%
plt.figure(figsize=(16,6))
plt.plot(X, y)
plt.plot(X, trendp)
plt.legend(['data', 'polynomial trend'])
plt.show()

# %%
plt.figure(figsize=(16,6))
detrpoly = [y[i] - trendp[i] for i in range(0, len(y))]
plt.plot(X, detrpoly)
plt.title('polynomially detrended data')
plt.show()

# %%
detrended = signal.detrend(daily_cases.new_cases)
plt.plot(detrended)

# %%
daily_cases.date = pd.to_datetime(daily_cases.date)
daily_cases = daily_cases.set_index('date')

# %%
plt.figure(figsize=(16,6))
result_mul = seasonal_decompose(daily_cases['new_cases'], model='multiplicative', extrapolate_trend='freq')
detrended = daily_cases.new_cases - result_mul.trend
plt.plot(detrended)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/a10.csv', parse_dates=['date'], index_col='date')

# %%
detrended.to_csv('detrended_cases.csv')

# %%
'42 999'.replace(' ','')
# Out:
# '42999'
